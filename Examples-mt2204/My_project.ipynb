# %% [markdown]
# This is my new python project

# %% [markdown]
# I don't know yet what the project is going be, here are some practice problems

# %%
x = 3
y = x**2

# %%
print (x)
print (y)
# Out:
# 3
# 9
