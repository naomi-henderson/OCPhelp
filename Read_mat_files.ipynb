# %% [markdown]
# ### Open .mat files

# %% [markdown]
# First we have to load function that works with Matlab files:

# %%
from scipy.io import loadmat
import numpy as np
# %matplotlib inline
import matplotlib.pylab as plt

# %% [markdown]
# We are going to download [Polar science center Hydrographic Climatology (PHC)](http://psc.apl.washington.edu/nonwp_projects/PHC/Climatology.html) for January in Matlab format.

# %%
# !wget https://www.dropbox.com/s/0kuzvz03gw6d393/PHC_jan.mat
# Out:
# --2018-04-11 10:36:03--  https://www.dropbox.com/s/0kuzvz03gw6d393/PHC_jan.mat
# Resolving www.dropbox.com... 162.125.4.1, 2620:100:6019:1::a27d:401
# Connecting to www.dropbox.com|162.125.4.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dl.dropboxusercontent.com/content_link/xL0V7RXBpdHgpUBM14pSECmQ26OKgJrDx5Gs2cfXbTglwBYYedktnslcM2SrFdJX/file [following]
# --2018-04-11 10:36:05--  https://dl.dropboxusercontent.com/content_link/xL0V7RXBpdHgpUBM14pSECmQ26OKgJrDx5Gs2cfXbTglwBYYedktnslcM2SrFdJX/file
# Resolving dl.dropboxusercontent.com... 162.125.4.6, 2620:100:6019:6::a27d:406
# Connecting to dl.dropboxusercontent.com|162.125.4.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9329048 (8.9M) [application/octet-stream]
# Saving to: ‘PHC_jan.mat.1’
#
# PHC_jan.mat.1       100%[===================>]   8.90M  --.-KB/s    in 0.1s
#
# 2018-04-11 10:36:06 (65.8 MB/s) - ‘PHC_jan.mat.1’ saved [9329048/9329048]

# %% [markdown]
# Open file:

# %%
all_variables = loadmat('PHC_jan.mat')

# %% [markdown]
# We can look at the names of variables stored in the file:

# %%
all_variables.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'LAT', 'LON', 'DEPTH', 'PTEMP1'])

# %% [markdown]
# We need only *PTEMP1* (3d potential temperature).

# %%
temp = np.array(all_variables['PTEMP1'])

# %% [markdown]
# Check variable's shape:

# %%
temp.shape
# Out:
# (33, 180, 360)

# %% [markdown]
# Show surface level:

# %%
plt.imshow(temp[0,:,:])
plt.colorbar();
